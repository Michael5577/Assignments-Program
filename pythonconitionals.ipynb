# %%
first = int(input("input first number: "))
second = int(input("input second number"))

if (first > second):
  print("first number is greater")
  print("Line goes with thw first condition")

  if (first < second):
    print("second number is greater")


    if (first == second):
      print ("both numbers are the same")
# Out:
# input first number: 75
# input scond number75

# %%
first = int(input("input first number: "))
second = int(input("input second number"))

if (first > second):
  print("first number is greater")
  print("Line goes with thw first condition")

  if (first< second):
    print("second number is greater")

    if (first == second):
      print ("both numbers are the same")
# Out:
# input first number: 57
# input second number58

# %%
examgrades = int (input("Enter your grade: "))

if (examgrades > 90 and examgrades <=100):
  print("Grade is an A")

  if (examgrades>=80 and examgrades <=90):
  print("Grade is a B")

  if (examgrades>=70 and examgrades <=80):
  print("Grade is a C")

  if (examgrades>=60 and examgrades <=70):
  print("Grade is a D")

  print(if (examgrades>=60 and examgrades <50):
  print("Grade is an  F"))
# Out:
#   File "<ipython-input-8-3a1e96a3d3ce>", line 7
#     print("Grade is a B")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 6

# %%
 birthyear  = int(input(=0 when divided by 2))
