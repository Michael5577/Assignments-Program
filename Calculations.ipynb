# %%
import circle
import rectangle_square

def main():
    choice = int(input("Enter 1 to calculate the area and circumference of a circle, 2 to calculate the area of a rectangle, and 3 to calculate the area of a square: "))

    if choice == 1:
        circle.main()
    elif choice == 2:
        rectangle_square.main()
    elif choice == 3:
        rectangle_square.main()
    else:
        print("Invalid choice.")

if __name__ == "__main__":
    main()
# https://pypi.python.org/pypi/pydot
# !apt-get -qq install -y graphviz && pip install pydot
import pydot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-8fcbb81b8b34> in <cell line: 2>()
#       1 import circle
# ----> 2 import rectangle_square
#       3
#       4 def main():
#       5     choice = int(input("Enter 1 to calculate the area and circumference of a circle, 2 to calculate the area of a rectangle, and 3 to calculate the area of a square: "))
#
# ModuleNotFoundError: No module named 'rectangle_square'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
