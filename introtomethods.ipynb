# %%
def main():
  college = ("input your college name: ")
  hello()
  print(college)

def hello():
  print("You go to : ")

main()
# Out:
# You go to :
# input your college name:

# %%
def main():
  college = ("input your college name: ")
  hello()
  print(college)

main()

def hello():
  print("You go to : ", college)

main()

# %%
def sum():
  a = int(input("Enter first value: "))
  b = int(input("Enter second value: "))
  result = (a+b)
  print(result)

sum()
# Out:
# Enter first value: 57
# Enter second value: 73
# 130

# %%
def sum(a=55.27, b=22.34):
  #a = int(input("Enter first value: "))
  #b = int(input("Enter second value: "))
  result = (a+b)
  print(result)

sum()
# Out:
# 77.61

# %%
km_to_mi = 0.6214
def main():
  #km_to_mi =0.6214

  x= int(input("enter x: "))
  if is_even(x):
    print("Even number")
  else:
    print("Odd number")

def is_even(n):
  if n%2 ==0:
    return True
  else:
    return False

main()
# Out:
# enter x: 56
# Even number
