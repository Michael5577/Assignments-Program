# %%
month = int(input("Input your month as a number"))

match month:
  case 1:
    print("You have entered January")
  case 2:
    print("You have entered February")
  case 3:
    print("You have entered March")
  case 4:
    print("You have entered April")
  case _:
    print("Inavalid nimber")
# Out:
# Input your month as a number5
# Inavalid nimber

# %%
carModel = str.lower(input("Enter your car model: "))

match carModel:
  case "honda":
    print ("It is a Japanese car")
  case "hyundai"

# %%
def switch (case):
  if case == "honda":
    print("It is a Japanese car")
  elif case == 'toyota':
    print("It is a Japanese car")
  elif case == "nissan":
    print("It is a Japanese car")
  elif case == "hyndai":
    print("It is a Korean car")
  elif case == "mercedez"
  print("It is a German car")
  else

# %%
print("*")
print("***")
print("******")
print("***")
print("*")
# Out:
# *
# ***
# ******
# ***
# *
